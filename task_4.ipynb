# %% [markdown]
# # Task 3
# ## Team 15
# - Ahmed Hossam Sedky
# - Ahmed Mohamed Abdelfattah
# - Ehab Wahba Abdelrahman
# - Mo'men Maged Mohamed
# - Mohaned Alaa Ragab

# %% [markdown]
# **Import numpy and the required image processing functions**
#
# *Note: cv2 is only imported to open the image and get its dimensions*

# %%
# from libs import normalization, equalization, filters, noise, graphs, edge_detection, threshold
from libs import colorMap,segmentation
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("images/deer.png")
b,g,r = cv2.split(img)       # get b,g,r
img = cv2.merge([r,g,b])     # switch it to rgb
cop_img = np.copy(img)
luv_img = colorMap.RGB2LUV(img)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(cop_img)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(luv_img )
ax[1].set_title('Luv Image')
ax[1].axis('image')

plt.tight_layout()
plt.show()

# %%
img = cv2.imread("images/test.png")
cop_img = np.copy(img)
segmented_image ,labels = segmentation.apply_k_means (img)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(cop_img)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(segmented_image )
ax[1].set_title('Luv Image')
ax[1].axis('image')

plt.tight_layout()
plt.show()
# Out:
# len cluster: 0 = 36993
# cluster_mean 0: [30.327873 40.807503 38.333145]
# len cluster: 1 = 81790
# cluster_mean 1: [44.616272 61.569935 37.3832  ]
# len cluster: 2 = 75749
# cluster_mean 2: [70.69295 96.24564 94.04335]
# len cluster: 3 = 107161
# cluster_mean 3: [138.38649 153.85863 145.99161]
# len cluster: 4 = 34899
# cluster_mean 4: [ 91.119804 102.83874   39.985073]
# len cluster: 0 = 49863
# cluster_mean 0: [28.600023 40.111588 29.994726]
# len cluster: 1 = 72024
# cluster_mean 1: [48.912292 66.280685 44.48906 ]
# len cluster: 2 = 93661
# cluster_mean 2: [73.55983  97.93226  95.670105]
# len cluster: 3 = 84969
# cluster_mean 3: [142.11528 157.64919 165.20999]
# len cluster: 4 = 36075
# cluster_mean 4: [117.02303  126.70578   26.089342]
# len cluster: 0 = 50427
# cluster_mean 0: [28.909573 40.5317   28.32663 ]
# len cluster: 1 = 89883
# cluster_mean 1: [51.52198  69.06519  47.911774]
# len cluster: 2 = 87696
# cluster_mean 2: [ 77.96821  102.146324 100.42572 ]
# len cluster: 3 = 77405
# cluster_mean 3: [143.10426 158.29811 171.65228]
# len cluster: 4 = 31181
# cluster_mean 4: [132.52843  142.71361   26.003206]
# len cluster: 0 = 58619
# cluster_mean 0: [30.735785 42.5836   28.933008]
# len cluster: 1 = 88641
# cluster_mean 1: [54.171593 72.12444  49.779842]
# len cluster: 2 = 86922
# cluster_mean 2: [ 80.07471  104.192055 103.36795 ]
# len cluster: 3 = 72795
# cluster_mean 3: [144.45874 159.47789 174.73875]
# len cluster: 4 = 29615
# cluster_mean 4: [136.95677 147.13338  27.88283]
# len cluster: 0 = 61546
# cluster_mean 0: [31.033699 43.36433  29.50689 ]
# len cluster: 1 = 92384
# cluster_mean 1: [55.276833 73.20017  52.313313]
# len cluster: 2 = 82782
# cluster_mean 2: [ 82.19555 106.63868 106.59288]
# len cluster: 3 = 70593
# cluster_mean 3: [145.93898 160.69391 175.26083]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 63561
# cluster_mean 0: [31.38135  43.7332   29.966347]
# len cluster: 1 = 98893
# cluster_mean 1: [56.259796 74.8816   54.92166 ]
# len cluster: 2 = 77464
# cluster_mean 2: [ 85.52248 109.68309 110.88985]
# len cluster: 3 = 67387
# cluster_mean 3: [147.5067  162.07237 176.87497]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 67655
# cluster_mean 0: [32.592358 45.132614 29.47751 ]
# len cluster: 1 = 97152
# cluster_mean 1: [56.78439 75.69837 56.86409]
# len cluster: 2 = 78976
# cluster_mean 2: [ 87.668884 111.39746  113.14511 ]
# len cluster: 3 = 63522
# cluster_mean 3: [149.20477 163.68555 179.31732]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 68921
# cluster_mean 0: [33.150913 45.55266  29.193207]
# len cluster: 1 = 99250
# cluster_mean 1: [57.07352 76.35127 58.44401]
# len cluster: 2 = 76546
# cluster_mean 2: [ 88.74776  112.596115 114.76521 ]
# len cluster: 3 = 62588
# cluster_mean 3: [149.87936 164.039   179.71005]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 75756
# cluster_mean 0: [34.997585 47.487366 29.182283]
# len cluster: 1 = 94427
# cluster_mean 1: [57.57773  77.48972  61.114597]
# len cluster: 2 = 75715
# cluster_mean 2: [ 89.96277 113.41142 115.86717]
# len cluster: 3 = 61407
# cluster_mean 3: [150.204   164.50133 180.6084 ]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 78240
# cluster_mean 0: [35.315147 47.94812  29.684471]
# len cluster: 1 = 95319
# cluster_mean 1: [58.270954 78.32912  62.702663]
# len cluster: 2 = 74210
# cluster_mean 2: [ 91.95086  115.080635 117.491264]
# len cluster: 3 = 59536
# cluster_mean 3: [150.87036 165.3656  181.85315]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 83998
# cluster_mean 0: [36.879284 49.505463 29.741268]
# len cluster: 1 = 92634
# cluster_mean 1: [58.59154  79.313805 65.74189 ]
# len cluster: 2 = 73262
# cluster_mean 2: [ 93.29644 116.50372 119.99813]
# len cluster: 3 = 57411
# cluster_mean 3: [152.63344 166.55768 182.29364]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 89099
# cluster_mean 0: [37.91635  50.619682 30.189575]
# len cluster: 1 = 92203
# cluster_mean 1: [59.796917 80.911156 68.38329 ]
# len cluster: 2 = 68592
# cluster_mean 2: [ 94.30655 117.65799 122.23638]
# len cluster: 3 = 57411
# cluster_mean 3: [152.63344 166.55768 182.29364]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 93122
# cluster_mean 0: [38.498173 51.242992 30.923658]
# len cluster: 1 = 90062
# cluster_mean 1: [60.38592 81.93507 70.03283]
# len cluster: 2 = 66710
# cluster_mean 2: [ 94.99228 118.269   122.80728]
# len cluster: 3 = 57411
# cluster_mean 3: [152.63344 166.55768 182.29364]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 97534
# cluster_mean 0: [38.708134 51.985584 31.892479]
# len cluster: 1 = 85650
# cluster_mean 1: [61.274315 82.67045  70.94418 ]
# len cluster: 2 = 67942
# cluster_mean 2: [ 95.608345 118.668655 123.280846]
# len cluster: 3 = 56179
# cluster_mean 3: [153.15244 167.1333  183.02545]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 97534
# cluster_mean 0: [38.708134 51.985584 31.892479]
# len cluster: 1 = 88335
# cluster_mean 1: [61.736107 83.16653  71.77366 ]
# len cluster: 2 = 65257
# cluster_mean 2: [ 96.39591  119.478294 124.31142 ]
# len cluster: 3 = 56179
# cluster_mean 3: [153.15244 167.1333  183.02545]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 98878
# cluster_mean 0: [38.902393 52.244038 32.097828]
# len cluster: 1 = 89945
# cluster_mean 1: [62.25607  83.9344   73.084206]
# len cluster: 2 = 62303
# cluster_mean 2: [ 97.47706  120.35385  125.444824]
# len cluster: 3 = 56179
# cluster_mean 3: [153.15244 167.1333  183.02545]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 102544
# cluster_mean 0: [39.645996 53.098904 32.411774]
# len cluster: 1 = 87125
# cluster_mean 1: [62.535828 84.53422  74.613266]
# len cluster: 2 = 62061
# cluster_mean 2: [ 97.81771 120.73679 126.3188 ]
# len cluster: 3 = 55575
# cluster_mean 3: [153.64317 167.34125 183.19962]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 103841
# cluster_mean 0: [40.1875   53.547318 32.23177 ]
# len cluster: 1 = 87503
# cluster_mean 1: [62.413666 84.85979  76.01494 ]
# len cluster: 2 = 60386
# cluster_mean 2: [ 98.53385 121.1733  126.93788]
# len cluster: 3 = 55575
# cluster_mean 3: [153.64317 167.34125 183.19962]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 103841
# cluster_mean 0: [40.1875   53.547318 32.23177 ]
# len cluster: 1 = 87743
# cluster_mean 1: [62.527416 84.96411  75.99848 ]
# len cluster: 2 = 61318
# cluster_mean 2: [ 99.17122  121.564224 127.60154 ]
# len cluster: 3 = 54403
# cluster_mean 3: [154.08788 167.88718 183.91484]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 103841
# cluster_mean 0: [40.1875   53.547318 32.23177 ]
# len cluster: 1 = 88483
# cluster_mean 1: [62.7739  85.11495 76.14903]
# len cluster: 2 = 62094
# cluster_mean 2: [100.18026 122.33322 128.42676]
# len cluster: 3 = 52887
# cluster_mean 3: [154.5777  168.5719  185.03033]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 103841
# cluster_mean 0: [40.1875   53.547318 32.23177 ]
# len cluster: 1 = 88483
# cluster_mean 1: [62.7739  85.11495 76.14903]
# len cluster: 2 = 63528
# cluster_mean 2: [101.124245 122.935165 128.66542 ]
# len cluster: 3 = 51453
# cluster_mean 3: [154.92824 169.11737 186.3132 ]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 103841
# cluster_mean 0: [40.1875   53.547318 32.23177 ]
# len cluster: 1 = 91239
# cluster_mean 1: [63.172493 85.7925   76.990005]
# len cluster: 2 = 62654
# cluster_mean 2: [102.56582 123.91817 131.35402]
# len cluster: 3 = 49571
# cluster_mean 3: [156.54744 170.48387 186.47554]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 108043
# cluster_mean 0: [40.429497 53.934998 33.36415 ]
# len cluster: 1 = 89458
# cluster_mean 1: [64.7794   87.361496 78.22063 ]
# len cluster: 2 = 61255
# cluster_mean 2: [103.06806 125.11086 133.43571]
# len cluster: 3 = 48549
# cluster_mean 3: [157.50444 170.89752 186.80663]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 109983
# cluster_mean 0: [40.527756 54.236008 33.781067]
# len cluster: 1 = 88556
# cluster_mean 1: [65.45126 87.90324 78.97596]
# len cluster: 2 = 60217
# cluster_mean 2: [103.34503  125.492004 133.96036 ]
# len cluster: 3 = 48549
# cluster_mean 3: [157.50444 170.89752 186.80663]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 109983
# cluster_mean 0: [40.527756 54.236008 33.781067]
# len cluster: 1 = 89997
# cluster_mean 1: [65.60416 88.12895 79.56877]
# len cluster: 2 = 58776
# cluster_mean 2: [104.03996  126.067955 134.4007  ]
# len cluster: 3 = 48549
# cluster_mean 3: [157.50444 170.89752 186.80663]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]
# len cluster: 0 = 109983
# cluster_mean 0: [40.527756 54.236008 33.781067]
# len cluster: 1 = 89997
# cluster_mean 1: [65.60416 88.12895 79.56877]
# len cluster: 2 = 58776
# cluster_mean 2: [104.03996  126.067955 134.4007  ]
# len cluster: 3 = 48549
# cluster_mean 3: [157.50444 170.89752 186.80663]
# len cluster: 4 = 29287
# cluster_mean 4: [137.0011   147.14607   27.119951]

# %%
img = cv2.imread("images/test.png")
cop_img = np.copy(img)
segmented_image = segmentation.apply_region_growing (img)
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
ax = axes.ravel()

ax[0].imshow(cop_img)
ax[0].set_title('Original Image')
ax[0].set_axis_off()

ax[1].imshow(segmented_image ,cmap = "gray")
ax[1].set_title('segmented Image')
ax[1].axis('image')

plt.tight_layout()
plt.show()
