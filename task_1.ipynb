# %% [markdown]
# # Task 1
# ## Team 15
# - Ahmed Hossam Sedky
# - Ahmed Mohamed Abdelfattah
# - Ehab Wahba Abdelrahman
# - Mo'men Maged Mohamed
# - Mohaned Alaa Ragab

# %% [markdown]
# **Import numpy and the required image processing functions**
#
# *Note: cv2 is only imported to open the image and get its dimensions*

# %%
from libs import normalization, equalization, resizeImg, filters, noise, graphs, Prewitt, Roberts, Sobel, Canny , hybrid
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# **Open the image**

# %%
image = cv2.imread("images/lenna.png")
# Rearrange RGB channels to use the image matrix correctly in matplotlib
b, g, r = cv2.split(image)
image = cv2.merge((r,g,b))
plt.imshow(image)
plt.show()

# %%
grayscale_image = filters.grayscale(image)
plt.imshow(grayscale_image, cmap = "gray")
plt.title("Grayscale image")
plt.show()

# %% [markdown]
# Image Histogram and Distribution Curve

# %%
graphs.histogram(image)

# %%
graphs.distribution_curve(image)

# %% [markdown]
# **Add noise to the image**

# %%
# Salt and Pepper noise
sp_noise_image = noise.sp_noise(image)
plt.imshow(sp_noise_image, cmap="gray")
plt.title("Salt and Pepper Noise")
plt.show()

# %%
# Salt and Pepper noise
Uniform_noise_image = noise.sp_noise(image)
plt.imshow(Uniform_noise_image, cmap="gray")
plt.title("Uniform Noise")
plt.show()

# %% [markdown]
# **Call the filters functions**

# %%
# Average Filter
# The average filter function takes 2 arguments, a gray-scaled image and the kernel size
# We can test the filter on the sp image using a 5x5 kernel
plt.imshow(filters.average_filter(sp_noise_image,5), cmap="gray")
plt.title("Average Filter on SP")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19468\1897964185.py in <module>
#       2 # The average filter function takes 2 arguments, a gray-scaled image and the kernel size
#       3 # We can test the filter on the sp image using a 5x5 kernel
# ----> 4 plt.imshow(filters.average_filter(sp_noise_image,5), cmap="gray")
#       5 plt.title("Average Filter on SP")
#       6 plt.show()
#
# d:\4th year 2nd term\cv\tasks\task1\task1\task1\libs\filters.py in average_filter(image, kernel_size)
#      21     kernel = kernel / (pow(kernel_size, 2))
#      22
# ---> 23     filtered_image = convolution(image, kernel)
#      24     filtered_image = filtered_image.astype(np.uint8)
#      25     return filtered_image
#
# d:\4th year 2nd term\cv\tasks\task1\task1\task1\libs\utils.py in convolution(image, kernel)
#      15         paddingHeight : padded_image.shape[0] - paddingHeight,
#      16         paddingWidth : padded_image.shape[1] - paddingWidth,
# ---> 17     ] = image
#      18     for row in range(len(image)):
#      19         for col in range(len(image[0])):
#
# ValueError: could not broadcast input array from shape (512,512,3) into shape (512,512)

# %% [markdown]
# Now let's test the median filter on the same image

# %%
# The median filter function takes only 1 argument which is a gray-scaled image
plt.imshow(filters.median_filter(gray_scale_image), cmap="gray")
plt.title("Median filter on S&P")
plt.show()
# Out:
# (512, 512)

# %% [markdown]
# We can see that all of the salt and pepper noise were removed.
# We will then test the gaussian blur filter on the raw image

# %%
# The gaussian blur function takes 3 arguments (grayScaleImage, kernelSize, standard deviation)
gaussian_blurred_image = filters.gaussian_filter(gray_scale_image,21,3)
plt.imshow(gaussian_blurred_image, cmap="gray")
plt.title("Gaussian Blur")
plt.show()

# %% [markdown]
# Then we can use the edge detection algorithms
# 1. Prewitt
# 2. Roberts
# 3. Sobel
# 4. Canny

# %%
#Prewitt
plt.imshow(Prewitt.prewitt(gray_scale_image))
plt.title("Prewitt Edge detection")
plt.show()

# %%
#Roberts
plt.imshow(Roberts.roberts(gray_scale_image))
plt.title("Roberts Edge detection")
plt.show()

# %%
#Sobel
plt.imshow(Sobel.sobel(gray_scale_image))
plt.title("Sobel Edge detection")
plt.show()

# %%
#Canny
plt.imshow(Canny.canny(gray_scale_image), cmap="gray")
plt.title("Canny Edge detection")
plt.show()

# %%
#call normalization "RGB"
img = Image.open("images/lenna.png")
new_max = 255
new_min = 100
normalization.normalize(img ,new_max ,new_min)
plt.imshow(img)
plt.title("Normalize image")
plt.show()

# %%
#call normalization "gray scale"
img = Image.open("images/lenna.png")
img = img.convert('L')
new_max = 255
new_min = 200
normalization.normalize(img ,new_max ,new_min)
plt.imshow(img,cmap="gray")
plt.title("Normalize img")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24000\1431310388.py in <module>
#       1 #call normalization "gray scale"
# ----> 2 img = Image.open("images/lenna.png")
#       3 img = img.convert('L')
#       4 new_max = 255
#       5 new_min = 200
#
# NameError: name 'Image' is not defined

# %%
#equalize image
img = cv2.imread('images/lenna.png') 
img = cv2.cvtColor(img , cv2.COLOR_BGR2GRAY)
equalization.equalize(img)
equaled_hist = equalization.Histogram (img)
plt.show()
plt.imshow(img,cmap="gray")
plt.title("equalized img")
plt.show()

# %%
img = cv2.imread('images/lenna.png') 
equalization.equalize(img)
equaled_hist = equalization.Histogram (img)
plt.show()
plt.imshow(img)
plt.title("Equalized image")
plt.show()
cv2.imshow('image',img) # show original image
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6912\4233726920.py in <module>
# ----> 1 img = cv2.imread('images/lenna.png')
#       2 equalization.equalize(img)
#       3 equaled_hist = equalization.Histogram (img)
#       4 plt.show()
#       5 plt.imshow(img)
#
# NameError: name 'cv2' is not defined

# %%
image = cv2.imread("images/elephant.jpg")
gray_scale_image = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)

image2 = cv2.imread("images/img2.png")
gray_scale_image2 = cv2.cvtColor(image2 , cv2.COLOR_BGR2GRAY)

hybrid_img = hybrid.hybrid(gray_scale_image , gray_scale_image2)
plt.imshow(hybrid_img,cmap="gray")
plt.title("Gray Scale Image")
plt.show()

# %%
#Frequency domain high pass filter

rows,cols = np.shape(grayscale_image)
fourierImage = fft.fft2(np.array(grayscale_image))
imgShift = fft.fftshift(fourierImage)
highPassImage = fft.highPassFiltering(imgShift,200)

plt.imshow(np.abs(fft.ifft2(fft.fftshift(highPassImage),rows,cols)),cmap = "gray")
plt.title("High pass filter")
plt.show()
